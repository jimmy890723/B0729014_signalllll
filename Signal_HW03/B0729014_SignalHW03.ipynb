# %%
# Get thinkdsp.py

import os

if not os.path.exists('thinkdsp.py'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py

# %%
import numpy as np
import matplotlib.pyplot as plt

from thinkdsp import decorate
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-1273731d756e> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 from thinkdsp import decorate
#
# ImportError: cannot import name 'decorate' from 'thinkdsp' (C:\Users\JenMing\thinkdsp.py)

# %%
import scipy.signal

gaussian = scipy.signal.gaussian(M=32, std=2)
gaussian /= sum(gaussian)
plt.plot(gaussian)
decorate(xlabel='Index')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-39477c0917e0> in <module>
#       4 gaussian /= sum(gaussian)
#       5 plt.plot(gaussian)
# ----> 6 decorate(xlabel='Index')
#
# NameError: name 'decorate' is not defined

# %%
fft_gaussian = np.fft.fft(gaussian)
plt.plot(abs(fft_gaussian))
decorate(xlabel='Frequency (Hz)', ylabel='Amplitude')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-941902b92d44> in <module>
#       1 fft_gaussian = np.fft.fft(gaussian)
#       2 plt.plot(abs(fft_gaussian))
# ----> 3 decorate(xlabel='Frequency (Hz)', ylabel='Amplitude')
#
# NameError: name 'decorate' is not defined

# %%
N = len(gaussian)
fft_rolled = np.roll(fft_gaussian, N//2)
plt.plot(abs(fft_rolled))
decorate(xlabel='Frequency (Hz)', ylabel='Amplitude')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-dd6ac8c2a75a> in <module>
#       2 fft_rolled = np.roll(fft_gaussian, N//2)
#       3 plt.plot(abs(fft_rolled))
# ----> 4 decorate(xlabel='Frequency (Hz)', ylabel='Amplitude')
#
# NameError: name 'decorate' is not defined

# %%
def plot_gaussian(std):
    M = 32
    gaussian = scipy.signal.gaussian(M=M, std=std)
    gaussian /= sum(gaussian)
    
    plt.subplot(1, 2, 1)
    plt.plot(gaussian)
    decorate(xlabel='Time')

    fft_gaussian = np.fft.fft(gaussian)
    fft_rolled = np.roll(fft_gaussian, M//2)
    
    plt.subplot(1, 2, 2)
    plt.plot(np.abs(fft_rolled))
    decorate(xlabel='Frequency')
    plt.show()

plot_gaussian(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a8f30dde1646> in <module>
#      16     plt.show()
#      17
# ---> 18 plot_gaussian(2)
#
# <ipython-input-15-a8f30dde1646> in plot_gaussian(std)
#       6     plt.subplot(1, 2, 1)
#       7     plt.plot(gaussian)
# ----> 8     decorate(xlabel='Time')
#       9
#      10     fft_gaussian = np.fft.fft(gaussian)
#
# NameError: name 'decorate' is not defined

# %%
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

slider = widgets.FloatSlider(min=0.1, max=10, value=2)
interact(plot_gaussian, std=slider);
# Out:
# interactive(children=(FloatSlider(value=2.0, description='std', max=10.0, min=0.1), Output()), _dom_classes=('…

# %%
from thinkdsp import SquareSignal

signal = SquareSignal(freq=440)
wave = signal.make_wave(duration=1.0, framerate=44100)

# %%
M = 15
std = 2.5

gaussian = scipy.signal.gaussian(M=M, std=std)   
bartlett = np.bartlett(M)
blackman = np.blackman(M)
hamming = np.hamming(M)
hanning = np.hanning(M)

windows = [blackman, gaussian, hanning, hamming]
names = ['blackman', 'gaussian', 'hanning', 'hamming']

for window in windows:
    window /= sum(window)

# %%
for window, name in zip(windows, names):
    plt.plot(window, label=name)

decorate(xlabel='Index')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-548622f0167f> in <module>
#       2     plt.plot(window, label=name)
#       3
# ----> 4 decorate(xlabel='Index')
#
# NameError: name 'decorate' is not defined

# %%
def zero_pad(array, n):
    """Extends an array with zeros.

    array: NumPy array
    n: length of result

    returns: new NumPy array
    """
    res = np.zeros(n)
    res[:len(array)] = array
    return res

# %%
def plot_window_dfts(windows, names):
    """
    """
    for window, name in zip(windows, names):
        padded =  zero_pad(window, len(wave))
        dft_window = np.fft.rfft(padded)
        plt.plot(abs(dft_window), label=name)

# %%
plot_window_dfts(windows, names)
decorate(xlabel='Frequency (Hz)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-6914101db851> in <module>
#       1 plot_window_dfts(windows, names)
# ----> 2 decorate(xlabel='Frequency (Hz)')
#
# NameError: name 'decorate' is not defined

# %%
plot_window_dfts(windows, names)
decorate(xlabel='Frequency (Hz)', yscale='log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-1968e9de5c32> in <module>
#       1 plot_window_dfts(windows, names)
# ----> 2 decorate(xlabel='Frequency (Hz)', yscale='log')
#
# NameError: name 'decorate' is not defined
