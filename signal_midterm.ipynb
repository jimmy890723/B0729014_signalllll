# %%
from thinkdsp import Chirp

import numpy as np

PI2 = 2 * np.pi

class JMTrombone(Chirp):
    """Represents a trombone-like signal with varying frequency."""
    
    def evaluate(self, ts):
        """Evaluates the signal at the given times.

        ts: float array of times
        
        returns: float wave array
        """
        l1, l2 = 1.0 / self.start, 1.0 / self.end
        lengths = np.linspace(l1, l2, len(ts))
        freqs = 1 / lengths
        
        dts = np.diff(ts, prepend=0)
        dphis = PI2 * freqs * dts
        phases = np.cumsum(dphis)
        ys = self.amp * np.cos(phases)
        return ys

# %%
low = 220
high = 440
signal = JMTrombone(high, low)
wave1 = signal.make_wave(duration=1)
wave1.apodize()
wave1.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
signal = JMTrombone(low, high)
wave2 = signal.make_wave(duration=1)
wave2.apodize()
wave2.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave = wave1 | wave2
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sp = wave.make_spectrogram(1024)
sp.plot(high=1000)

# %%
x= td.UncorrelatedGaussianNoise()
x= x.make_wave(duration= 1, framerate= 10000)

# %%
x.ts, x.ys
x.ys.shape
# Out:
# (10000,)

# %%
import matplotlib.pyplot as pl
pl.plot(x.ts, x.ys)

# %%
x.ys.max(), x.ys.mean(), x.ys.std()
# Out:
# (3.4991206270292095, 0.015506523837980268, 1.0112080426072791)

# %%
sx= x.make_spectrum()
sx.fs, sx.hs 
sx.hs.shape
# Out:
# (5001,)

# %%
sx.plot()

# %%
sx.plot_power()

# %%
Sx= sx.make_integrated_spectrum()
Sx.cs.shape
# Out:
# (5001,)

# %%
Sx.plot_power()

# %%
Sx.estimate_slope()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-178-098356675605> in <module>
# ----> 1 Sx.estimate_slope()
#
# ~\thinkdsp.py in estimate_slope(self, low, high)
#     479         x = np.log(self.fs[low:high])
#     480         y = np.log(self.cs[low:high])
# --> 481         t = scipy.stats.linregress(x, y)
#     482         return t
#     483
#
# D:\Anaconda\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#     107
#     108     if x.size == 0 or y.size == 0:
# --> 109         raise ValueError("Inputs must not be empty.")
#     110
#     111     n = len(x)
#
# ValueError: Inputs must not be empty.

# %%
Sx.plot_power()
pl.xscale('log')
pl.yscale('log')
pl.grid(True)

# %%
Sx.estimate_slope()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-172-098356675605> in <module>
# ----> 1 Sx.estimate_slope()
#
# ~\thinkdsp.py in estimate_slope(self, low, high)
#     479         x = np.log(self.fs[low:high])
#     480         y = np.log(self.cs[low:high])
# --> 481         t = scipy.stats.linregress(x, y)
#     482         return t
#     483
#
# D:\Anaconda\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#     107
#     108     if x.size == 0 or y.size == 0:
# --> 109         raise ValueError("Inputs must not be empty.")
#     110
#     111     n = len(x)
#
# ValueError: Inputs must not be empty.

# %%
y= x.cumsum()
x.ys.shape, y.ys.shape
# Out:
# ((10000,), (10000,))

# %%
y.plot()

# %%
y.ys.max(), y.ys.mean(), y.ys.std()
# Out:
# (170.55535298665504, 72.79526336329829, 43.09532298294825)

# %%
sy= y.make_spectrum()
sy.plot_power()
pl.xscale('log')
pl.yscale('log')
pl.grid(True)

# %%
sy.make_integrated_spectrum().plot_power()
pl.xscale('log')
pl.yscale('log')
pl.grid(True)

# %%
sy.make_integrated_spectrum().estimate_slope()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-1b5d83cf91b4> in <module>
# ----> 1 sy.make_integrated_spectrum().estimate_slope()
#
# ~\thinkdsp.py in estimate_slope(self, low, high)
#     479         x = np.log(self.fs[low:high])
#     480         y = np.log(self.cs[low:high])
# --> 481         t = scipy.stats.linregress(x, y)
#     482         return t
#     483
#
# D:\Anaconda\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#     107
#     108     if x.size == 0 or y.size == 0:
# --> 109         raise ValueError("Inputs must not be empty.")
#     110
#     111     n = len(x)
#
# ValueError: Inputs must not be empty.

# %%
z= td.BrownianNoise().make_wave(duration=1, framerate=10000)
z.plot()

# %%
z.make_spectrum().make_integrated_spectrum().estimate_slope()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-82fa107f3ce5> in <module>
# ----> 1 z.make_spectrum().make_integrated_spectrum().estimate_slope()
#
# ~\thinkdsp.py in estimate_slope(self, low, high)
#     479         x = np.log(self.fs[low:high])
#     480         y = np.log(self.cs[low:high])
# --> 481         t = scipy.stats.linregress(x, y)
#     482         return t
#     483
#
# D:\Anaconda\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#     107
#     108     if x.size == 0 or y.size == 0:
# --> 109         raise ValueError("Inputs must not be empty.")
#     110
#     111     n = len(x)
#
# ValueError: Inputs must not be empty.

# %%
aUrl= 'https://query1.finance.yahoo.com/v7/finance/download/%5EGSPC?period1=-1325635200&period2=1588550400&interval=1d&events=history'
import pandas as pd
df= pd.read_csv(aUrl)

# %%
df
# Out:
#              Date         Open         High          Low        Close  \
# 0      1927-12-30    17.660000    17.660000    17.660000    17.660000
# 1      1928-01-03    17.760000    17.760000    17.760000    17.760000
# 2      1928-01-04    17.719999    17.719999    17.719999    17.719999
# 3      1928-01-05    17.549999    17.549999    17.549999    17.549999
# 4      1928-01-06    17.660000    17.660000    17.660000    17.660000
# ...           ...          ...          ...          ...          ...
# 23188  2020-04-27  2854.649902  2887.719971  2852.889893  2878.479980
# 23189  2020-04-28  2909.959961  2921.149902  2860.709961  2863.389893
# 23190  2020-04-29  2918.459961  2954.860107  2912.159912  2939.510010
# 23191  2020-04-30  2930.909912  2930.909912  2892.469971  2912.429932
# 23192  2020-05-01  2869.090088  2869.090088  2821.610107  2830.709961
#
#          Adj Close      Volume
# 0        17.660000           0
# 1        17.760000           0
# 2        17.719999           0
# 3        17.549999           0
# 4        17.660000           0
# ...            ...         ...
# 23188  2878.479980  5194260000
# 23189  2863.389893  5672880000
# 23190  2939.510010  6620140000
# 23191  2912.429932  6523120000
# 23192  2830.709961  4753160000
#
# [23193 rows x 7 columns]

# %%
ys= df['Close'].values
ys= ys[-5000:]
pl.plot(ys)

# %%
yWave= td.Wave(ys, framerate= 10000)

# %%
yWave.plot()

# %%
yWave.make_spectrum().make_integrated_spectrum().plot_power()
pl.xscale('log')
pl.yscale('log')

# %%
yWave.make_spectrum().make_integrated_spectrum().estimate_slope()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-e4776ff7dfad> in <module>
# ----> 1 yWave.make_spectrum().make_integrated_spectrum().estimate_slope()
#
# ~\thinkdsp.py in estimate_slope(self, low, high)
#     479         x = np.log(self.fs[low:high])
#     480         y = np.log(self.cs[low:high])
# --> 481         t = scipy.stats.linregress(x, y)
#     482         return t
#     483
#
# D:\Anaconda\lib\site-packages\scipy\stats\_stats_mstats_common.py in linregress(x, y)
#     107
#     108     if x.size == 0 or y.size == 0:
# --> 109         raise ValueError("Inputs must not be empty.")
#     110
#     111     n = len(x)
#
# ValueError: Inputs must not be empty.
